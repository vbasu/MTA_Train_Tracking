# %%
from constants import *
import requests
from google.transit import gtfs_realtime_pb2
from google.protobuf.json_format import MessageToDict
import pandas as pd
from datetime import datetime
import time
import glob
import os

# %%
# Get the stop id -> stop name data
stop_id_to_name = pd.read_csv('Data/google_transit/stops.txt')
stop_lookup_dict = stop_id_to_name.set_index('stop_id')['stop_name'].to_dict()

# %%
# Create dataframe/database
db = pd.DataFrame(columns=['trip_id',
                           'line',
                           'stop_id', 
                           'stop_name', 
                           'arrival_time', 
                           'departure_time', 
                           'trip_date', 
                           'update_time'
                          ])

# %%
def poll_trip_updates():
    url = SUBWAY_FEEDS['1']
    data_update_time = datetime.now()
    res = requests.get(url, headers={"x-api-key": API_KEY})
    feed = gtfs_realtime_pb2.FeedMessage()
    feed.ParseFromString(res.content)
    
    message_array_all = MessageToDict(feed).get('entity')
    trip_updates = list(filter(lambda x: 'tripUpdate' in x, message_array_all))
    
    return trip_updates, data_update_time

# %%
def parse_trip_update(trip_updates, update_time):
    message_data = []
    for message in trip_updates:
        trip_update = message.get('tripUpdate')
        trip_date = trip_update.get('trip').get('startDate')
        trip_id = trip_update.get('trip').get('tripId')
        line = trip_update.get('trip').get('routeId')
        
        stop_time_updates = trip_update.get('stopTimeUpdate')
        for stop_time_update in stop_time_updates:
            stop_id = stop_time_update.get('stopId')
            stop_name = stop_lookup_dict.get(stop_id)
            
            stop_update_info_all = {'trip_id': trip_id,
                                    'trip_date': trip_date,
                                    'line': line,
                                    'stop_id': stop_id,
                                    'stop_name': stop_name,
                                    'update_time': update_time}
            
            if 'arrival' in stop_time_update:
                arrival_time = stop_time_update.get('arrival').get('time')
                arrival_time_readable = datetime.fromtimestamp(int(arrival_time))
                stop_update_info_all['arrival_time'] = arrival_time_readable
            else:
                stop_update_info_all['arrival_time'] = None
                
            if 'departure' in stop_time_update:
                departure_time = stop_time_update.get('departure').get('time')
                departure_time_readable = datetime.fromtimestamp(int(departure_time))
                stop_update_info_all['departure_time'] = departure_time_readable
            else:
                stop_update_info_all['departure_time'] = None
                
            message_data.append(stop_update_info_all)
    
    return message_data

# %%
#Pull an instance of data
raw_trip_updates, data_update_time = poll_trip_updates()
message_data = parse_trip_update(raw_trip_updates, data_update_time)
db = pd.concat([db, pd.DataFrame(data=message_data)], ignore_index=True)
display(db)
# Out:
#                 trip_id line stop_id                  stop_name  \
# 0     144300_6..N04X001    6    415N     149 St-Grand Concourse
# 1     145700_6..N04X001    6    415N     149 St-Grand Concourse
# 2     147200_6..N04X001    6    415N     149 St-Grand Concourse
# 3     148700_6..N04X001    6    415N     149 St-Grand Concourse
# 4     018500_6..S04X102    6    640S  Brooklyn Bridge-City Hall
# ...                 ...  ...     ...                        ...
# 1625        117050_7..N    7    707N              Junction Blvd
# 1626        117050_7..N    7    706N        103 St-Corona Plaza
# 1627        117050_7..N    7    705N                     111 St
# 1628        117050_7..N    7    702N         Mets-Willets Point
# 1629        117050_7..N    7    701N           Flushing-Main St
#
#             arrival_time      departure_time trip_date  \
# 0    2023-06-07 00:34:37                 NaT  20230607
# 1    2023-06-07 00:56:23                 NaT  20230607
# 2    2023-06-07 01:09:52                 NaT  20230607
# 3    2023-06-07 01:34:42                 NaT  20230607
# 4    2023-06-07 03:33:43                 NaT  20230607
# ...                  ...                 ...       ...
# 1625 2023-06-06 19:59:10 2023-06-06 19:59:30  20230606
# 1626 2023-06-06 20:00:40 2023-06-06 20:01:00  20230606
# 1627 2023-06-06 20:02:10 2023-06-06 20:02:30  20230606
# 1628 2023-06-06 20:04:40 2023-06-06 20:05:00  20230606
# 1629 2023-06-06 20:07:10                 NaT  20230606
#
#                     update_time
# 0    2023-06-07 03:32:08.449037
# 1    2023-06-07 03:32:08.449037
# 2    2023-06-07 03:32:08.449037
# 3    2023-06-07 03:32:08.449037
# 4    2023-06-07 03:32:08.449037
# ...                         ...
# 1625 2023-06-07 03:32:08.449037
# 1626 2023-06-07 03:32:08.449037
# 1627 2023-06-07 03:32:08.449037
# 1628 2023-06-07 03:32:08.449037
# 1629 2023-06-07 03:32:08.449037
#
# [1630 rows x 8 columns]

# %%
db['line'].unique()
# Out:
# array(['6', '1', '2', '3', '4', '5', '7', '7X'], dtype=object)

# %%
time = datetime.now()
display(db.query("stop_name=='Fulton St' and arrival_time>@time"))
# Out:
#                 trip_id line stop_id  stop_name        arrival_time  \
# 361      013900_2..S08R    2    229S  Fulton St 2023-06-07 03:39:04
# 422      015900_2..S08R    2    229S  Fulton St 2023-06-07 03:59:57
# 509      017900_2..S08R    2    229S  Fulton St 2023-06-07 04:17:59
# 532      019350_2..N08R    2    229N  Fulton St 2023-06-07 03:40:46
# 611      019900_2..S08R    2    229S  Fulton St 2023-06-07 04:32:22
# 646      021350_2..N08R    2    229N  Fulton St 2023-06-07 04:03:30
# 733      021900_2..S08R    2    229S  Fulton St 2023-06-07 04:50:00
# 768      023350_2..N08R    2    229N  Fulton St 2023-06-07 04:23:30
# 855      023400_2..S08R    2    229S  Fulton St 2023-06-07 05:05:00
# 1007  017500_4..S13X038    4    418S  Fulton St 2023-06-07 03:46:57
# 1031  018700_4..N13X008    4    418N  Fulton St 2023-06-07 03:40:48
# 1082  019500_4..S13X038    4    418S  Fulton St 2023-06-07 04:05:24
# 1117  020700_4..N13X008    4    418N  Fulton St 2023-06-07 04:04:27
# 1179  021500_4..S13X038    4    418S  Fulton St 2023-06-07 04:25:30
# 1218  022700_4..N13X008    4    418N  Fulton St 2023-06-07 04:24:00
# 1280  023500_4..S13X038    4    418S  Fulton St 2023-06-07 04:45:30
#
#           departure_time trip_date                update_time
# 361  2023-06-07 03:39:04  20230607 2023-06-07 03:32:08.449037
# 422  2023-06-07 03:59:57  20230607 2023-06-07 03:32:08.449037
# 509  2023-06-07 04:17:59  20230607 2023-06-07 03:32:08.449037
# 532  2023-06-07 03:40:46  20230607 2023-06-07 03:32:08.449037
# 611  2023-06-07 04:32:22  20230607 2023-06-07 03:32:08.449037
# 646  2023-06-07 04:03:30  20230607 2023-06-07 03:32:08.449037
# 733  2023-06-07 04:50:00  20230607 2023-06-07 03:32:08.449037
# 768  2023-06-07 04:23:30  20230607 2023-06-07 03:32:08.449037
# 855  2023-06-07 05:05:00  20230607 2023-06-07 03:32:08.449037
# 1007 2023-06-07 03:46:57  20230607 2023-06-07 03:32:08.449037
# 1031 2023-06-07 03:40:48  20230607 2023-06-07 03:32:08.449037
# 1082 2023-06-07 04:05:24  20230607 2023-06-07 03:32:08.449037
# 1117 2023-06-07 04:04:27  20230607 2023-06-07 03:32:08.449037
# 1179 2023-06-07 04:25:30  20230607 2023-06-07 03:32:08.449037
# 1218 2023-06-07 04:24:00  20230607 2023-06-07 03:32:08.449037
# 1280 2023-06-07 04:45:30  20230607 2023-06-07 03:32:08.449037

# %%
def print_trip_updates(trip_updates):
    for message in trip_updates:
        trip_update = message.get('tripUpdate')
        trip_date = trip_update.get('trip').get('startDate')
        trip_id = trip_update.get('trip').get('tripId')

        print('Trip date: {}, Trip Id: {}\n'.format(trip_date, trip_id))

        stop_time_updates = trip_update.get('stopTimeUpdate')
        for stop_time_update in stop_time_updates:
            stop_id = stop_time_update.get('stopId')
            stop_name = stop_lookup_dict.get(stop_id)
            print('Stop Location: {} '.format(stop_name))

            if 'arrival' in stop_time_update:
                arrival_time = stop_time_update.get('arrival').get('time')
                arrival_time_readable = datetime.fromtimestamp(int(arrival_time))
                print('Arrival time: {}'.format(arrival_time_readable))

            if 'departure' in stop_time_update:
                departure_time = stop_time_update.get('departure').get('time')
                departure_time_readable = datetime.fromtimestamp(int(departure_time))
                print('Departure time: {}'.format(departure_time_readable))

        print("---------------------\n")

# %%
def poll_and_update():
    raw_trip_updates, data_update_time = poll_trip_updates()
    message_data = parse_trip_update(raw_trip_updates, data_update_time)
    date = data_update_time.date()
    time = data_update_time.time()
    pd.DataFrame(data=message_data).to_csv(
        'Data/train_timing_data/{}/train_data_{}.csv'.format(date, time), index=False)

# %%
for i in range(120):
    poll_and_update()
    time.sleep(60)

# %%
#Gather up data
path = r'Data/train_timing_data/2023-03-30'
all_files = glob.glob(os.path.join(path, "*.csv"))
df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)

# %%
df['update_time'] = pd.to_datetime(df['update_time'])
df['arrival_time'] = pd.to_datetime(df['arrival_time'])

# %%
df.query("trip_id=='082550_1..N03R' and stop_name=='72 St'").sort_values('update_time')
# Out:
#                trip_id  trip_date line stop_id stop_name  \
# 313635  082550_1..N03R   20230330    1    123N     72 St
# 5888    082550_1..N03R   20230330    1    123N     72 St
# 447505  082550_1..N03R   20230330    1    123N     72 St
# 432980  082550_1..N03R   20230330    1    123N     72 St
# 180094  082550_1..N03R   20230330    1    123N     72 St
# 348417  082550_1..N03R   20230330    1    123N     72 St
# 487434  082550_1..N03R   20230330    1    123N     72 St
# 219484  082550_1..N03R   20230330    1    123N     72 St
# 397905  082550_1..N03R   20230330    1    123N     72 St
# 263811  082550_1..N03R   20230330    1    123N     72 St
# 55688   082550_1..N03R   20230330    1    123N     72 St
# 382939  082550_1..N03R   20230330    1    123N     72 St
# 586466  082550_1..N03R   20230330    1    123N     72 St
# 591518  082550_1..N03R   20230330    1    123N     72 St
# 402779  082550_1..N03R   20230330    1    123N     72 St
# 40672   082550_1..N03R   20230330    1    123N     72 St
# 189915  082550_1..N03R   20230330    1    123N     72 St
# 278912  082550_1..N03R   20230330    1    123N     72 St
# 209518  082550_1..N03R   20230330    1    123N     72 St
# 551768  082550_1..N03R   20230330    1    123N     72 St
# 60765   082550_1..N03R   20230330    1    123N     72 St
# 169903  082550_1..N03R   20230330    1    123N     72 St
# 601411  082550_1..N03R   20230330    1    123N     72 St
# 303479  082550_1..N03R   20230330    1    123N     72 St
# 164860  082550_1..N03R   20230330    1    123N     72 St
# 457181  082550_1..N03R   20230330    1    123N     72 St
# 338162  082550_1..N03R   20230330    1    123N     72 St
# 546672  082550_1..N03R   20230330    1    123N     72 St
# 492247  082550_1..N03R   20230330    1    123N     72 St
# 35604   082550_1..N03R   20230330    1    123N     72 St
# 273490  082550_1..N03R   20230330    1    123N     72 St
# 293337  082550_1..N03R   20230330    1    123N     72 St
# 370     082550_1..N03R   20230330    1    123N     72 St
# 596246  082550_1..N03R   20230330    1    123N     72 St
# 467303  082550_1..N03R   20230330    1    123N     72 St
# 184545  082550_1..N03R   20230330    1    123N     72 St
# 462182  082550_1..N03R   20230330    1    123N     72 St
# 452013  082550_1..N03R   20230330    1    123N     72 St
# 392734  082550_1..N03R   20230330    1    123N     72 St
# 308352  082550_1..N03R   20230330    1    123N     72 St
# 115564  082550_1..N03R   20230330    1    123N     72 St
# 556416  082550_1..N03R   20230330    1    123N     72 St
# 367981  082550_1..N03R   20230330    1    123N     72 St
# 194679  082550_1..N03R   20230330    1    123N     72 St
# 288461  082550_1..N03R   20230330    1    123N     72 St
# 20473   082550_1..N03R   20230330    1    123N     72 St
# 224031  082550_1..N03R   20230330    1    123N     72 St
# 482007  082550_1..N03R   20230330    1    123N     72 St
# 95929   082550_1..N03R   20230330    1    123N     72 St
# 25468   082550_1..N03R   20230330    1    123N     72 St
# 521679  082550_1..N03R   20230330    1    123N     72 St
# 536510  082550_1..N03R   20230330    1    123N     72 St
# 496896  082550_1..N03R   20230330    1    123N     72 St
# 120444  082550_1..N03R   20230330    1    123N     72 St
# 526653  082550_1..N03R   20230330    1    123N     72 St
# 75714   082550_1..N03R   20230330    1    123N     72 St
#
#                       update_time        arrival_time       departure_time
# 313635 2023-03-30 13:13:24.270506 2023-03-30 14:08:00  2023-03-30 14:08:00
# 5888   2023-03-30 13:14:24.494670 2023-03-30 14:08:00  2023-03-30 14:08:00
# 447505 2023-03-30 13:15:24.815882 2023-03-30 14:08:00  2023-03-30 14:08:00
# 432980 2023-03-30 13:16:25.046732 2023-03-30 14:08:00  2023-03-30 14:08:00
# 180094 2023-03-30 13:17:25.349553 2023-03-30 14:08:00  2023-03-30 14:08:00
# 348417 2023-03-30 13:18:25.649604 2023-03-30 14:08:00  2023-03-30 14:08:00
# 487434 2023-03-30 13:19:25.910463 2023-03-30 14:08:00  2023-03-30 14:08:00
# 219484 2023-03-30 13:20:26.214493 2023-03-30 14:08:00  2023-03-30 14:08:00
# 397905 2023-03-30 13:21:26.436638 2023-03-30 14:08:00  2023-03-30 14:08:00
# 263811 2023-03-30 13:22:26.755814 2023-03-30 14:08:00  2023-03-30 14:08:00
# 55688  2023-03-30 13:23:27.071548 2023-03-30 14:08:00  2023-03-30 14:08:00
# 382939 2023-03-30 13:24:27.310453 2023-03-30 14:08:00  2023-03-30 14:08:00
# 586466 2023-03-30 13:25:27.558723 2023-03-30 14:08:00  2023-03-30 14:08:00
# 591518 2023-03-30 13:26:27.742944 2023-03-30 14:08:00  2023-03-30 14:08:00
# 402779 2023-03-30 13:27:28.022448 2023-03-30 14:08:00  2023-03-30 14:08:00
# 40672  2023-03-30 13:28:28.331847 2023-03-30 14:08:00  2023-03-30 14:08:00
# 189915 2023-03-30 13:29:28.579621 2023-03-30 14:08:00  2023-03-30 14:08:00
# 278912 2023-03-30 13:30:28.831558 2023-03-30 14:08:00  2023-03-30 14:08:00
# 209518 2023-03-30 13:31:29.230648 2023-03-30 14:08:00  2023-03-30 14:08:00
# 551768 2023-03-30 13:32:29.597052 2023-03-30 14:08:00  2023-03-30 14:08:00
# 60765  2023-03-30 13:33:29.898279 2023-03-30 14:08:00  2023-03-30 14:08:00
# 169903 2023-03-30 13:34:30.187477 2023-03-30 14:08:00  2023-03-30 14:08:00
# 601411 2023-03-30 13:35:30.463636 2023-03-30 14:08:00  2023-03-30 14:08:00
# 303479 2023-03-30 13:36:30.731687 2023-03-30 14:08:00  2023-03-30 14:08:00
# 164860 2023-03-30 13:37:31.002888 2023-03-30 14:08:00  2023-03-30 14:08:00
# 457181 2023-03-30 13:38:31.302515 2023-03-30 14:08:00  2023-03-30 14:08:00
# 338162 2023-03-30 13:39:31.543209 2023-03-30 14:08:00  2023-03-30 14:08:00
# 546672 2023-03-30 13:40:31.814419 2023-03-30 14:08:00  2023-03-30 14:08:00
# 492247 2023-03-30 13:41:32.015943 2023-03-30 14:08:00  2023-03-30 14:08:00
# 35604  2023-03-30 13:42:32.294488 2023-03-30 14:08:00  2023-03-30 14:08:00
# 273490 2023-03-30 13:43:32.556294 2023-03-30 14:08:00  2023-03-30 14:08:00
# 293337 2023-03-30 13:44:32.830660 2023-03-30 14:08:00  2023-03-30 14:08:00
# 370    2023-03-30 13:45:33.038178 2023-03-30 14:08:00  2023-03-30 14:08:00
# 596246 2023-03-30 13:46:33.298436 2023-03-30 14:08:01  2023-03-30 14:08:01
# 467303 2023-03-30 13:47:33.581108 2023-03-30 14:08:12  2023-03-30 14:08:12
# 184545 2023-03-30 13:48:33.819629 2023-03-30 14:07:40  2023-03-30 14:07:40
# 462182 2023-03-30 13:49:34.203914 2023-03-30 14:07:54  2023-03-30 14:07:54
# 452013 2023-03-30 13:50:34.496696 2023-03-30 14:08:16  2023-03-30 14:08:16
# 392734 2023-03-30 13:51:34.773619 2023-03-30 14:08:16  2023-03-30 14:08:16
# 308352 2023-03-30 13:52:35.006832 2023-03-30 14:08:25  2023-03-30 14:08:25
# 115564 2023-03-30 13:53:35.270499 2023-03-30 14:07:46  2023-03-30 14:07:46
# 556416 2023-03-30 13:54:35.564063 2023-03-30 14:07:24  2023-03-30 14:07:24
# 367981 2023-03-30 13:55:35.877983 2023-03-30 14:07:09  2023-03-30 14:07:09
# 194679 2023-03-30 13:56:36.095109 2023-03-30 14:07:11  2023-03-30 14:07:11
# 288461 2023-03-30 13:57:36.350512 2023-03-30 14:07:10  2023-03-30 14:07:10
# 20473  2023-03-30 13:58:36.574435 2023-03-30 14:07:16  2023-03-30 14:07:16
# 224031 2023-03-30 13:59:36.854637 2023-03-30 14:07:30  2023-03-30 14:07:30
# 482007 2023-03-30 14:00:37.159084 2023-03-30 14:07:43  2023-03-30 14:07:43
# 95929  2023-03-30 14:01:37.438449 2023-03-30 14:07:25  2023-03-30 14:07:25
# 25468  2023-03-30 14:02:37.714433 2023-03-30 14:08:00  2023-03-30 14:08:00
# 521679 2023-03-30 14:03:38.028901 2023-03-30 14:08:09  2023-03-30 14:08:09
# 536510 2023-03-30 14:04:38.322435 2023-03-30 14:08:29  2023-03-30 14:08:29
# 496896 2023-03-30 14:05:38.656269 2023-03-30 14:07:49  2023-03-30 14:07:49
# 120444 2023-03-30 14:06:38.922291 2023-03-30 14:07:42  2023-03-30 14:07:42
# 526653 2023-03-30 14:07:39.218199 2023-03-30 14:08:03  2023-03-30 14:08:03
# 75714  2023-03-30 14:08:39.574617 2023-03-30 14:08:08  2023-03-30 14:08:08

# %%
time = datetime.now()
df.query("stop_name=='Fulton St' and arrival_time<@time").groupby('line').agg({'arrival_time': 'max', 'update_time': 'max'})
# Out:
#             arrival_time                update_time
# line
# 2    2023-03-30 15:48:00 2023-03-30 14:14:41.294504
# 3    2023-03-30 15:22:30 2023-03-30 14:14:41.294504
# 4    2023-03-30 15:33:30 2023-03-30 14:14:41.294504
# 5    2023-03-30 15:39:30 2023-03-30 14:14:41.294504

# %%
import functools
functools.reduce(lambda x, y: x + y, [[1,2,3], [3,4,5]], [])
# Out:
# [1, 2, 3, 3, 4, 5]

# %%
#db.query("trip_id=='096100_1..S03R' and stop_name=='Chambers St'")
